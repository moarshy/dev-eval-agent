# %%
import sys
sys.path.append("/Users/arshath/play/naptha/devagent/agents")

from dotenv import load_dotenv
load_dotenv()

from nest_asyncio import apply
apply()

# %%
import json
import dspy
import pickle
import json
import time
import subprocess
import traceback
from typing import Dict, Any
from IPython.display import display, Markdown, HTML
from pydantic import BaseModel
from typing import Optional, Union, Dict, Any, List

from doc_ingestion.fetcher import WebsiteFetcher
from doc_ingestion.crawl4ai import create_crawl4ai_fetcher
from doc_ingestion.analyzer import DocumentAnalyzer
from test_plan import TestPlanGenerator
from concurrent.futures import ThreadPoolExecutor, as_completed

dspy.configure(lm=dspy.LM("gemini/gemini-2.5-flash", max_tokens=30000))

# %%
# fetcher = WebsiteFetcher()
# contents = fetcher.fetch("https://openweathermap.org/api")
# pages = json.loads(contents.content['pages'])

# %%
# crawl4ai_fetcher = create_crawl4ai_fetcher(
#     crawl_type="deep", 
#     max_pages=100, 
#     max_depth=3, 
#     keywords=["api", "documentation"]
# )

# crawl4ai_contents = crawl4ai_fetcher.fetch("https://openweathermap.org/api")

# %%
# with open('crewai-data.pkl', 'wb') as f:
#     pickle.dump(crawl4ai_contents, f)

with open('crewai-data.pkl', 'rb') as f:
    crawl4ai_contents = pickle.load(f)

# %%
crawl4ai_contents.content
# Out:
# {'https://openweathermap.org/api': "![banner android](https://openweathermap.org/themes/openweathermap/assets/img/mobile_app/android-app-top-banner.png)\nOpenWeather\nOpenWeather Ltd.\nGET - on Google Play\n  * [ ![logo](https://openweathermap.org/themes/openweathermap/assets/img/logo_white_cropped.png) ](https://openweathermap.org/)\n  * ![icon hamburger](https://openweathermap.org/themes/openweathermap/assets/img/owm_icons/icon_hamburger.svg)\n  *     * [Guide](https://openweathermap.org/guide)\n    * [API](https://openweathermap.org/api)\n    * [Marketplace](https://home.openweathermap.org/marketplace)\n    * [Pricing](https://openweathermap.org/price)\n    * [Maps](https://openweathermap.org/weathermap)\n    * [Our Initiatives](https://openweathermap.org/our-initiatives)\n    * [Partners](https://openweathermap.org/examples)\n    * [Sign in](https://openweathermap.org/home/sign_in)\n    * [Support centre](https://openweathermap.org/support-centre)\n\n\n  *   * [Guide](https://openweathermap.org/guide)\n  * [API](https://openweathermap.org/api)\n  * [Marketplace](https://home.openweathermap.org/marketplace)\n  * [Pricing](https://openweathermap.org/price)\n  * [Maps](https://openweathermap.org/weathermap)\n  * [Our Initiatives](https://openweathermap.org/our-initiatives)\n  * [Partners](https://openweathermap.org/examples)\n  * [Support centre](https://openweathermap.org/support-centre)\n  * [Sign in](https://openweathermap.org/home/sign_in)\n\n\n# Weather API\n  1. [Home](https://openweathermap.org/)\n  2. Weather API\n\n\nPlease, [sign up](https://openweathermap.org/home/sign_up) to use our fast and easy-to-work weather APIs. As a start to use OpenWeather products, we recommend our [One Call API 3.0](https://openweathermap.org/api/one-call-3). For more functionality, please consider our products, which are included in [professional collections](https://openweathermap.org/api#pro). \n##  [One Call API 3.0](https://openweathermap.org/api/one-call-3)\n[API doc](https://openweathermap.org/api/one-call-3) [Subscribe](https://home.openweathermap.org/subscriptions/unauth_subscribe/onecall_30/base)\nMake an API call to receive access to the various data:\n  * [**Current weather and forecasts:**](https://openweathermap.org/api/one-call-3#current)\n    * minute forecast for 1 hour\n    * hourly forecast for 48 hours\n    * daily forecast for 8 days\nand government weather alerts \n  * [ **Weather data for any timestamp**](https://openweathermap.org/api/one-call-3#history) for 46+ years historical archive and 4 days ahead forecast\n  * [**Daily aggregation**](https://openweathermap.org/api/one-call-3#history_daily_aggregation) of weather data for 46+ years archive and 1.5 years ahead forecast\n  * [**Weather overview**](https://openweathermap.org/api/one-call-3#weather_overview) with a human-readable weather summary for today and tomorrow's forecast\n\n\nRead more about this API and subscription plan in the [**FAQ**](https://openweathermap.org/faq#onecall). \n  \n\n### Pay as you call\n  \n\n###  **1,000** API calls per day for free  \n**0.0012 GBP** per API call over the daily limit\n  \n\n[Subscribe](https://home.openweathermap.org/subscriptions/unauth_subscribe/onecall_30/base)\n  \n\nThis is a separate subscription plan, which includes only One Call API.\n  \n\n## Professional collections\nFor professionals and specialists with middle sized project, we recommend our Professional collections, which included [Current & Forecasts collection](https://openweathermap.org/api#current), [Historical weather data collection](https://openweathermap.org/api#history), [Weather Maps collection](https://openweathermap.org/api#maps) and other APIs. \nFor Enterprise level projects we provide Enterprise license, which is included all forecast products and current state, along with alerts, maps, and other products. \nYou can read the [How to Start](https://openweathermap.org/appid) guide and enjoy using our powerful weather APIs right now.\n## Cur ...
#  'https://openweathermap.org/api/accumulated-parameters': '![banner android](https://openweathermap.org/themes/openweathermap/assets/img/mobile_app/android-app-top-banner.png)\nOpenWeather\nOpenWeather Ltd.\nGET - on Google Play\n  * [ ![logo](https://openweathermap.org/themes/openweathermap/assets/img/logo_white_cropped.png) ](https://openweathermap.org/)\n  * ![icon hamburger](https://openweathermap.org/themes/openweathermap/assets/img/owm_icons/icon_hamburger.svg)\n  *     * [Guide](https://openweathermap.org/guide)\n    * [API](https://openweathermap.org/api)\n    * [Marketplace](https://home.openweathermap.org/marketplace)\n    * [Pricing](https://openweathermap.org/price)\n    * [Maps](https://openweathermap.org/weathermap)\n    * [Our Initiatives](https://openweathermap.org/our-initiatives)\n    * [Partners](https://openweathermap.org/examples)\n    * [Sign in](https://openweathermap.org/home/sign_in)\n    * [Support centre](https://openweathermap.org/support-centre)\n\n\n  *   * [Guide](https://openweathermap.org/guide)\n  * [API](https://openweathermap.org/api)\n  * [Marketplace](https://home.openweathermap.org/marketplace)\n  * [Pricing](https://openweathermap.org/price)\n  * [Maps](https://openweathermap.org/weathermap)\n  * [Our Initiatives](https://openweathermap.org/our-initiatives)\n  * [Partners](https://openweathermap.org/examples)\n  * [Support centre](https://openweathermap.org/support-centre)\n  * [Sign in](https://openweathermap.org/home/sign_in)\n\n\n# Accumulated Parameters\n  1. [Home](https://openweathermap.org/)\n  2. [API](https://openweathermap.org/api)\n  3. Accumulated Parameters\n\n\n  * [Accumulated temperature](https://openweathermap.org/api/accumulated-parameters#temp)\n    * [How to make an API call](https://openweathermap.org/api/accumulated-parameters#temp_geo)\n    * [Example of API response](https://openweathermap.org/api/accumulated-parameters#temp_resp)\n    * [Fields in API response](https://openweathermap.org/api/accumulated-parameters#temp_param)\n  * [Accumulated precipitation](https://openweathermap.org/api/accumulated-parameters#precip)\n    * [How to make an API call](https://openweathermap.org/api/accumulated-parameters#precip_geo)\n    * [Example of API response](https://openweathermap.org/api/accumulated-parameters#precip_resp)\n    * [Fields in API response](https://openweathermap.org/api/accumulated-parameters#precip_param)\n  * [Other features](https://openweathermap.org/api/accumulated-parameters#other)\n    * [Geocoding API](https://openweathermap.org/api/accumulated-parameters#geocoding)\n    * [Built-in geocoding](https://openweathermap.org/api/accumulated-parameters#builtin)\n      * [Built-in API request by city name](https://openweathermap.org/api/accumulated-parameters#name)\n      * [Built-in API request by city ID](https://openweathermap.org/api/accumulated-parameters#cityid)\n\n\nThe Accumulated Parameters include accumulated temperature and accumulated precipitation.\n  * Accumulated temperature is the sum, counted in degrees, by which the actual air temperature rises above or falls below a threshold level during the chosen time period.\n  * Accumulated precipitation is the sum, counted in millimeters, of daily precipitation during the chosen time period.\n\n\n## Accumulated temperature\n### How to make an API call \nAPI call\n`http://history.openweathermap.org/data/2.5/history/accumulated_temperature?lat={lat}&lon={lon}&start={start}&end={end}&threshold={threshold}&appid=[{API key}](https://home.openweathermap.org/api_keys)`\nCopy\n![](https://openweathermap.org/themes/openweathermap/assets/img/documentation/copy.png)\nParameters  \n---  \n`lat, lon` | required | Geographical coordinates (latitude, longitude). If you need the geocoder to automatic convert city names and zip-codes to geo coordinates and the other way around, please use our [Geocoding API](https://openweathermap.org/api/geocoding-api).  \n`start` | required | Start date (unix time, UTC time zone) ...
#  'https://openweathermap.org/api/history-forecast-bulk': '![banner android](https://openweathermap.org/themes/openweathermap/assets/img/mobile_app/android-app-top-banner.png)\nOpenWeather\nOpenWeather Ltd.\nGET - on Google Play\n  * [ ![logo](https://openweathermap.org/themes/openweathermap/assets/img/logo_white_cropped.png) ](https://openweathermap.org/)\n  * ![icon hamburger](https://openweathermap.org/themes/openweathermap/assets/img/owm_icons/icon_hamburger.svg)\n  *     * [Guide](https://openweathermap.org/guide)\n    * [API](https://openweathermap.org/api)\n    * [Marketplace](https://home.openweathermap.org/marketplace)\n    * [Pricing](https://openweathermap.org/price)\n    * [Maps](https://openweathermap.org/weathermap)\n    * [Our Initiatives](https://openweathermap.org/our-initiatives)\n    * [Partners](https://openweathermap.org/examples)\n    * [Sign in](https://openweathermap.org/home/sign_in)\n    * [Support centre](https://openweathermap.org/support-centre)\n\n\n  *   * [Guide](https://openweathermap.org/guide)\n  * [API](https://openweathermap.org/api)\n  * [Marketplace](https://home.openweathermap.org/marketplace)\n  * [Pricing](https://openweathermap.org/price)\n  * [Maps](https://openweathermap.org/weathermap)\n  * [Our Initiatives](https://openweathermap.org/our-initiatives)\n  * [Partners](https://openweathermap.org/examples)\n  * [Support centre](https://openweathermap.org/support-centre)\n  * [Sign in](https://openweathermap.org/home/sign_in)\n\n\n# History Forecast Bulk\n  1. [Home](https://openweathermap.org/)\n  2. [API](https://openweathermap.org/api)\n  3. History Forecast Bulk\n\n\n  * [About History Forecast Bulk](https://openweathermap.org/api/history-forecast-bulk#about)\n  * [Product structure](https://openweathermap.org/api/history-forecast-bulk#structure)\n  * [How to get History Forecast Bulk](https://openweathermap.org/api/history-forecast-bulk#buy)\n  * [Fields in History Forecast Bulk](https://openweathermap.org/api/history-forecast-bulk#parameter)\n    * [JSON format](https://openweathermap.org/api/history-forecast-bulk#json)\n    * [CSV format](https://openweathermap.org/api/history-forecast-bulk#csv)\n  * [Sample data and examples](https://openweathermap.org/api/history-forecast-bulk#sample_and_response)\n    * [JSON sample and example](https://openweathermap.org/api/history-forecast-bulk#json_example)\n    * [CSV sample and example](https://openweathermap.org/api/history-forecast-bulk#csv_example)\n\n\nThis service allows to extract historical forecast weather data from October 7, 2017 for any location on the globe.\nWe provide historical 16-day forecasts with 1-hour step, please find detailed description in the ["Product structure"](https://openweathermap.org/api/history-forecast-bulk#structure) and ["Fields in History Forecast Bulk"](https://openweathermap.org/api/history-forecast-bulk#parameter) sections. \n## About History Forecast Bulk\nHistory Forecast Bulk provides an archive of previous forecasts starting from October 7, 2017.\nBy using this service, you can receive data on previously made 16-day forecasts for any coordinates on the globe.  \n\nThere are two formats this can be provided in: CSV and JSON.\nThe examples of data can be found in the ["Sample data and examples"](https://openweathermap.org/api/history-forecast-bulk#sample_and_response) section.\nPlease \n[Buy History Forecast Bulk](https://home.openweathermap.org/history_forecast_bulks/new)\n## Product structure\nHistorical forecast data is available from 7 October 2017.\nA 16-day forecast is a set of values for weather parameters for each of the 16 days ahead. \nThere are 4 model recalculation cycles available for each day. Each time when recalculation happens, the new forecast is generated (it updates values of weather parameters in the forecast). It means that for each day, starting from 7 October 2017, you will have four 16-day forecasts. \nForecasts are updated at these times: 00:00 UTC, 06:00 UTC, 12:00 UTC,  ...
#  'https://openweathermap.org/api/fire-index-api': '![banner android](https://openweathermap.org/themes/openweathermap/assets/img/mobile_app/android-app-top-banner.png)\nOpenWeather\nOpenWeather Ltd.\nGET - on Google Play\n  * [ ![logo](https://openweathermap.org/themes/openweathermap/assets/img/logo_white_cropped.png) ](https://openweathermap.org/)\n  * ![icon hamburger](https://openweathermap.org/themes/openweathermap/assets/img/owm_icons/icon_hamburger.svg)\n  *     * [Guide](https://openweathermap.org/guide)\n    * [API](https://openweathermap.org/api)\n    * [Marketplace](https://home.openweathermap.org/marketplace)\n    * [Pricing](https://openweathermap.org/price)\n    * [Maps](https://openweathermap.org/weathermap)\n    * [Our Initiatives](https://openweathermap.org/our-initiatives)\n    * [Partners](https://openweathermap.org/examples)\n    * [Sign in](https://openweathermap.org/home/sign_in)\n    * [Support centre](https://openweathermap.org/support-centre)\n\n\n  *   * [Guide](https://openweathermap.org/guide)\n  * [API](https://openweathermap.org/api)\n  * [Marketplace](https://home.openweathermap.org/marketplace)\n  * [Pricing](https://openweathermap.org/price)\n  * [Maps](https://openweathermap.org/weathermap)\n  * [Our Initiatives](https://openweathermap.org/our-initiatives)\n  * [Partners](https://openweathermap.org/examples)\n  * [Support centre](https://openweathermap.org/support-centre)\n  * [Sign in](https://openweathermap.org/home/sign_in)\n\n\n# Fire Weather Index API\n  1. [Home](https://openweathermap.org/)\n  2. [API](https://openweathermap.org/api)\n  3. Fire Weather Index API\n\n\n  * [Fire Weather Index API concept](https://openweathermap.org/api/fire-index-api#concept)\n    * [Fire Weather Index range values](https://openweathermap.org/api/fire-index-api#fwi-range)\n  * [How to get access to Fire Weather Index data](https://openweathermap.org/api/fire-index-api#access)\n  * [Call Current FIre Weather Index data](https://openweathermap.org/api/fire-index-api#current)\n    * [How to make an API call](https://openweathermap.org/api/fire-index-api#how)\n    * [Example of API response](https://openweathermap.org/api/fire-index-api#example)\n    * [Fields in API response](https://openweathermap.org/api/fire-index-api#parameter)\n  * [Call Forecast FIre Weather Index data](https://openweathermap.org/api/fire-index-api#forecast)\n    * [How to make an API call](https://openweathermap.org/api/fire-index-api#forecast-how)\n    * [Example of API response](https://openweathermap.org/api/fire-index-api#forecast_example)\n    * [Fields in API response](https://openweathermap.org/api/fire-index-api#forecast_parameter)\n  * [API errors](https://openweathermap.org/api/fire-index-api#errors)\n\n\n## Fire Weather Index API concept\nThis product provides users with [current ](https://openweathermap.org/api/fire-index-api#current) and [forecast ](https://openweathermap.org/api/fire-index-api#forecast) Fire Weather Index data for any coordinates on the globe. Data is available in the JSON format. Fire Weather Index forecast is available for 5 days ahead with a daily step.\nYou could obtain current and forecast fire weather index data as map product. Read more about Fire Weather Map [here](https://openweathermap.org/api/fire-index-map).\nFire Weather Index API is designed to help users to estimate current and forecast fire danger. Predictions of fire danger conditions based on the Canadian Forest Service Fire Weather Index Rating System (FWI).\nFire Weather Index (FWI) is a numerical rating of the potential frontal fire intensity and indicates fire intensity by combining the rate of fire spread with the amount of fuel being consumed.\n### Fire Weather Index range values\nFWI is classified in 6 classes of danger (very low, low, medium, high, very high and extreme). The fire danger classes are the same for all countries and show a harmonized picture of the spatial distribution of fire danger level. The following are the FWI ...
#  'https://openweathermap.org/api/air-pollution': '![banner android](https://openweathermap.org/themes/openweathermap/assets/img/mobile_app/android-app-top-banner.png)\nOpenWeather\nOpenWeather Ltd.\nGET - on Google Play\n  * [ ![logo](https://openweathermap.org/themes/openweathermap/assets/img/logo_white_cropped.png) ](https://openweathermap.org/)\n  * ![icon hamburger](https://openweathermap.org/themes/openweathermap/assets/img/owm_icons/icon_hamburger.svg)\n  *     * [Guide](https://openweathermap.org/guide)\n    * [API](https://openweathermap.org/api)\n    * [Marketplace](https://home.openweathermap.org/marketplace)\n    * [Pricing](https://openweathermap.org/price)\n    * [Maps](https://openweathermap.org/weathermap)\n    * [Our Initiatives](https://openweathermap.org/our-initiatives)\n    * [Partners](https://openweathermap.org/examples)\n    * [Sign in](https://openweathermap.org/home/sign_in)\n    * [Support centre](https://openweathermap.org/support-centre)\n\n\n  *   * [Guide](https://openweathermap.org/guide)\n  * [API](https://openweathermap.org/api)\n  * [Marketplace](https://home.openweathermap.org/marketplace)\n  * [Pricing](https://openweathermap.org/price)\n  * [Maps](https://openweathermap.org/weathermap)\n  * [Our Initiatives](https://openweathermap.org/our-initiatives)\n  * [Partners](https://openweathermap.org/examples)\n  * [Support centre](https://openweathermap.org/support-centre)\n  * [Sign in](https://openweathermap.org/home/sign_in)\n\n\n# Air Pollution API\n  1. [Home](https://openweathermap.org/)\n  2. [API](https://openweathermap.org/api)\n  3. Air Pollution API\n\n\n  * [Air Pollution API concept](https://openweathermap.org/api/air-pollution#concept)\n  * [Current air pollution data](https://openweathermap.org/api/air-pollution#current)\n  * [Forecast air pollution data](https://openweathermap.org/api/air-pollution#forecast)\n  * [Historical air pollution data](https://openweathermap.org/api/air-pollution#history)\n  * [Air Pollution API response](https://openweathermap.org/api/air-pollution#descr)\n    * [Example of API response](https://openweathermap.org/api/air-pollution#descr)\n    * [Fields in API response](https://openweathermap.org/api/air-pollution#fields)\n  * [Air Pollution Index levels scale](https://openweathermap.org/air-pollution-index-levels)\n\n\n## Air Pollution API concept\nAir Pollution API provides current, forecast and historical air pollution data for any coordinates on the globe.\nBesides basic Air Quality Index, the API returns data about polluting gases, such as Carbon monoxide (CO), Nitrogen monoxide (NO), Nitrogen dioxide (NO2), Ozone (O3), Sulphur dioxide (SO2), Ammonia (NH3), and particulates (PM2.5 and PM10). \nAir pollution forecast is available for 4 days with hourly granularity. Historical data is accessible from 27th November 2020. \nHere is a description of OpenWeather scale for Air Quality Index levels:\nQualitative name | Index | Pollutant concentration in μg/m3  \n---|---|---  \n| SO2 | NO2 | PM10 | PM2.5 | O3 | CO  \nGood | 1 | [0; 20) | [0; 40) | [0; 20) | [0; 10) | [0; 60) | [0; 4400)  \nFair | 2 | [20; 80) | [40; 70) | [20; 50) | [10; 25) | [60; 100) | [4400; 9400)  \nModerate | 3 | [80; 250) | [70; 150) | [50; 100) | [25; 50) | [100; 140) | [9400-12400)  \nPoor | 4 | [250; 350) | [150; 200) | [100; 200) | [50; 75) | [140; 180) | [12400; 15400)  \nVery Poor | 5 | ⩾350 | ⩾200 | ⩾200 | ⩾75 | ⩾180 | ⩾15400  \nOther parameters that do not affect the AQI calculation:\n  * NH3: min value 0.1 - max value 200\n  * NO: min value 0.1 - max value 100\n\n\nPlease find Air Quality Index levels scales used in UK, Europe, USA and Mainland China in the ["Air Pollution Index levels scale"](https://openweathermap.org/air-pollution-index-levels) page.\n## Current air pollution data\nAPI call\n`http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid=[{API key}](https://home.openweathermap.org/api_keys)`\nCopy\n![](https://openweathermap.org/themes/open ...
#  'https://openweathermap.org/api/forecast30': '![banner android](https://openweathermap.org/themes/openweathermap/assets/img/mobile_app/android-app-top-banner.png)\nOpenWeather\nOpenWeather Ltd.\nGET - on Google Play\n  * [ ![logo](https://openweathermap.org/themes/openweathermap/assets/img/logo_white_cropped.png) ](https://openweathermap.org/)\n  * ![icon hamburger](https://openweathermap.org/themes/openweathermap/assets/img/owm_icons/icon_hamburger.svg)\n  *     * [Guide](https://openweathermap.org/guide)\n    * [API](https://openweathermap.org/api)\n    * [Marketplace](https://home.openweathermap.org/marketplace)\n    * [Pricing](https://openweathermap.org/price)\n    * [Maps](https://openweathermap.org/weathermap)\n    * [Our Initiatives](https://openweathermap.org/our-initiatives)\n    * [Partners](https://openweathermap.org/examples)\n    * [Sign in](https://openweathermap.org/home/sign_in)\n    * [Support centre](https://openweathermap.org/support-centre)\n\n\n  *   * [Guide](https://openweathermap.org/guide)\n  * [API](https://openweathermap.org/api)\n  * [Marketplace](https://home.openweathermap.org/marketplace)\n  * [Pricing](https://openweathermap.org/price)\n  * [Maps](https://openweathermap.org/weathermap)\n  * [Our Initiatives](https://openweathermap.org/our-initiatives)\n  * [Partners](https://openweathermap.org/examples)\n  * [Support centre](https://openweathermap.org/support-centre)\n  * [Sign in](https://openweathermap.org/home/sign_in)\n\n\n# Climatic forecast for 30 days\n  1. [Home](https://openweathermap.org/)\n  2. [API](https://openweathermap.org/api)\n  3. Climatic forecast for 30 days\n\n\n  * [Product concept](https://openweathermap.org/api/forecast30#concept)\n  * [Call weather forecast for 30 days](https://openweathermap.org/api/forecast30#year)\n    * [How to make an API call](https://openweathermap.org/api/forecast30#geo-year)\n    * [Example of API response](https://openweathermap.org/api/forecast30#resp-year)\n    * [Fields in API response](https://openweathermap.org/api/forecast30#fields)\n    * [List of weather condition codes](https://openweathermap.org/api/forecast30#list)\n  * [Other features](https://openweathermap.org/api/forecast30#other)\n    * [Geocoding API](https://openweathermap.org/api/forecast30#geocoding)\n    * [Built-in geocoding](https://openweathermap.org/api/forecast30#builtin)\n      * [Built-in API request by city name](https://openweathermap.org/api/forecast30#name-year)\n      * [Built-in API request by city ID](https://openweathermap.org/api/forecast30#cityid-year)\n      * [Built-in API request by ZIP code](https://openweathermap.org/api/forecast30#zip-year)\n    * [Format](https://openweathermap.org/api/forecast30#format)\n    * [Limitation of result](https://openweathermap.org/api/forecast30#limit)\n    * [Units of measurement](https://openweathermap.org/api/forecast30#data)\n    * [Multilingual support](https://openweathermap.org/api/forecast30#multi)\n    * [Call back function for JavaScript code](https://openweathermap.org/api/forecast30#call)\n\n\n## Product concept\nClimatic forecast 30 Days allows you to request daily weather data for the next 30 days. Data is available in JSON and XML formats. \n## Call weather forecast for 30 days\n### How to make an API call \nAPI call\n`https://pro.openweathermap.org/data/2.5/forecast/climate?lat={lat}&lon={lon}&appid=[{API key}](https://home.openweathermap.org/api_keys)`\nCopy\n![](https://openweathermap.org/themes/openweathermap/assets/img/documentation/copy.png)\nParameters  \n---  \n`lat` | required | Latitude. If you need the geocoder to automatic convert city names and zip-codes to geo coordinates and the other way around, please use our [Geocoding API](https://openweathermap.org/api/geocoding-api)  \n`lon` | required | Longitude. If you need the geocoder to automatic convert city names and zip-codes to geo coordinates and the other way around, please use our [Geocoding API](https://openweathermap.org/api/geocoding- ...
#  'https://openweathermap.org/api/one-call-3': '![banner android](https://openweathermap.org/themes/openweathermap/assets/img/mobile_app/android-app-top-banner.png)\nOpenWeather\nOpenWeather Ltd.\nGET - on Google Play\n  * [ ![logo](https://openweathermap.org/themes/openweathermap/assets/img/logo_white_cropped.png) ](https://openweathermap.org/)\n  * ![icon hamburger](https://openweathermap.org/themes/openweathermap/assets/img/owm_icons/icon_hamburger.svg)\n  *     * [Guide](https://openweathermap.org/guide)\n    * [API](https://openweathermap.org/api)\n    * [Marketplace](https://home.openweathermap.org/marketplace)\n    * [Pricing](https://openweathermap.org/price)\n    * [Maps](https://openweathermap.org/weathermap)\n    * [Our Initiatives](https://openweathermap.org/our-initiatives)\n    * [Partners](https://openweathermap.org/examples)\n    * [Sign in](https://openweathermap.org/home/sign_in)\n    * [Support centre](https://openweathermap.org/support-centre)\n\n\n  *   * [Guide](https://openweathermap.org/guide)\n  * [API](https://openweathermap.org/api)\n  * [Marketplace](https://home.openweathermap.org/marketplace)\n  * [Pricing](https://openweathermap.org/price)\n  * [Maps](https://openweathermap.org/weathermap)\n  * [Our Initiatives](https://openweathermap.org/our-initiatives)\n  * [Partners](https://openweathermap.org/examples)\n  * [Support centre](https://openweathermap.org/support-centre)\n  * [Sign in](https://openweathermap.org/home/sign_in)\n\n\n# One Call API 3.0\n  1. [Home](https://openweathermap.org/)\n  2. [API](https://openweathermap.org/api)\n  3. One Call API 3.0\n\n\n  * [Product concept](https://openweathermap.org/api/one-call-3#concept)\n  * [ How to start](https://openweathermap.org/api/one-call-3#start)\n  * [Current and forecasts weather data](https://openweathermap.org/api/one-call-3#current)\n    * [How to make an API call](https://openweathermap.org/api/one-call-3#how)\n    * [Example of API response](https://openweathermap.org/api/one-call-3#example)\n    * [Fields in API response](https://openweathermap.org/api/one-call-3#parameter)\n  * [Weather data for timestamp](https://openweathermap.org/api/one-call-3#history)\n    * [How to make an API call](https://openweathermap.org/api/one-call-3#history-how)\n    * [Example of API response](https://openweathermap.org/api/one-call-3#hist_example)\n    * [Fields in API response](https://openweathermap.org/api/one-call-3#hist_parameter)\n  * [Daily aggregation ](https://openweathermap.org/api/one-call-3#history_daily_aggregation)\n    * [How to make an API call](https://openweathermap.org/api/one-call-3#history_daily_aggregation_how)\n    * [Example of API response](https://openweathermap.org/api/one-call-3#hist_agr_example)\n    * [Fields in API response](https://openweathermap.org/api/one-call-3#hist_agr_parameter)\n  * [Weather overview](https://openweathermap.org/api/one-call-3#weather_overview)\n    * [How to make an API call](https://openweathermap.org/api/one-call-3#weather_overview_how)\n    * [Example of API response](https://openweathermap.org/api/one-call-3#weather_overview_example)\n    * [Fields in API response](https://openweathermap.org/api/one-call-3#weather_overview_response)\n  * [Other features](https://openweathermap.org/api/one-call-3#other)\n    * [List of weather condition codes](https://openweathermap.org/api/one-call-3#list1)\n    * [Units of measurement](https://openweathermap.org/api/one-call-3#data)\n    * [Multilingual support](https://openweathermap.org/api/one-call-3#multi)\n    * [List of national weather alerts sources](https://openweathermap.org/api/one-call-3#listsource)\n    * [Call back function for JavaScript code](https://openweathermap.org/api/one-call-3#call)\n  * [API errors](https://openweathermap.org/api/one-call-3#errors)\n    * [Structure of API errors](https://openweathermap.org/api/one-call-3#errorstructure)\n    * [Errors list](https://openweathermap.org/api/one-call-3#popularerrors)\n      * [Error 400] ...
#  'https://openweathermap.org/api/global-precipitation-map-forecast': '![banner android](https://openweathermap.org/themes/openweathermap/assets/img/mobile_app/android-app-top-banner.png)\nOpenWeather\nOpenWeather Ltd.\nGET - on Google Play\n  * [ ![logo](https://openweathermap.org/themes/openweathermap/assets/img/logo_white_cropped.png) ](https://openweathermap.org/)\n  * ![icon hamburger](https://openweathermap.org/themes/openweathermap/assets/img/owm_icons/icon_hamburger.svg)\n  *     * [Guide](https://openweathermap.org/guide)\n    * [API](https://openweathermap.org/api)\n    * [Marketplace](https://home.openweathermap.org/marketplace)\n    * [Pricing](https://openweathermap.org/price)\n    * [Maps](https://openweathermap.org/weathermap)\n    * [Our Initiatives](https://openweathermap.org/our-initiatives)\n    * [Partners](https://openweathermap.org/examples)\n    * [Sign in](https://openweathermap.org/home/sign_in)\n    * [Support centre](https://openweathermap.org/support-centre)\n\n\n  *   * [Guide](https://openweathermap.org/guide)\n  * [API](https://openweathermap.org/api)\n  * [Marketplace](https://home.openweathermap.org/marketplace)\n  * [Pricing](https://openweathermap.org/price)\n  * [Maps](https://openweathermap.org/weathermap)\n  * [Our Initiatives](https://openweathermap.org/our-initiatives)\n  * [Partners](https://openweathermap.org/examples)\n  * [Support centre](https://openweathermap.org/support-centre)\n  * [Sign in](https://openweathermap.org/home/sign_in)\n\n\n# Global Precipitation Maps History&Forecast\n  1. [Home](https://openweathermap.org/)\n  2. [API](https://openweathermap.org/api)\n  3. Global Precipitation Maps History&Forecast\n\n\n  * [Features of Global Precipitation Map](https://openweathermap.org/api/global-precipitation-map-forecast#features)\n  * [URL format and parameters](https://openweathermap.org/api/global-precipitation-map-forecast#url)\n  * [Example of Global Precipitation Map layer](https://openweathermap.org/api/global-precipitation-map-forecast#example)\n  * [Libraries to connect weather layers](https://openweathermap.org/api/global-precipitation-map-forecast#library)\n\n\nGet current, forecast and historical global precipitation weather maps with a 10 minutes-step via the easy-to-work API. \n## Features of Global Precipitation Map\n  1. This product includes two types of forecasts:\n     * Forecast for the next **6 hours** for the US territory \n     * Forecast for the next **2 hours** for other global areas  \n\n  2. Historical weather map for the previous 2 days\n  3. Update period: every 10 minutes\n  4. Resolution: less than 1 km\n  5. Global coverage\n  6. Weather map layers: Precipitation layer\n  7. Weather sources:\nGlobal Precipitatoin Map is based on global weather models, satellites, radars and our OWM NWP-ML technology.\n  8. There is the [OpenWeather Interactive Weather Maps](https://openweathermap.org/weathermap?basemap=map&cities=true&layer=radar&lat=56.9510&lon=24.1064&zoom=5) with Global Precipitation layer, which provide users with free access to visual data.\n\n\n## URL format and parameters\nUse the following URL format and parameters to get weather maps. Please pay attention to the URL example. \nAPI call\n`                   https://maps.openweathermap.org/maps/2.0/radar/forecast/{z}/{x}/{y}?appid=[{API key}](https://home.openweathermap.org/api_keys)&tm={date}                   `\nCopy\n![](https://openweathermap.org/themes/openweathermap/assets/img/documentation/copy.png)\nParameters  \n---  \n`{z}` | required | Number of zoom level  \nThe minimum value is **3** , and the maximum value is **7**.  \nYou could find information about correlation between zoom levels, X, Y tile coordinate numbers and level scale [here](https://openweathermap.org/faq#zoom_levels)  \n`{x}` | required | Number of x tile coordinate. You could find information about correlation between zoom levels, X, Y tile coordinate numbers and level scale [here](https://openweathermap.org/faq#z ...
#  'https://openweathermap.org/api/global-precipitation-map': '![banner android](https://openweathermap.org/themes/openweathermap/assets/img/mobile_app/android-app-top-banner.png)\nOpenWeather\nOpenWeather Ltd.\nGET - on Google Play\n  * [ ![logo](https://openweathermap.org/themes/openweathermap/assets/img/logo_white_cropped.png) ](https://openweathermap.org/)\n  * ![icon hamburger](https://openweathermap.org/themes/openweathermap/assets/img/owm_icons/icon_hamburger.svg)\n  *     * [Guide](https://openweathermap.org/guide)\n    * [API](https://openweathermap.org/api)\n    * [Marketplace](https://home.openweathermap.org/marketplace)\n    * [Pricing](https://openweathermap.org/price)\n    * [Maps](https://openweathermap.org/weathermap)\n    * [Our Initiatives](https://openweathermap.org/our-initiatives)\n    * [Partners](https://openweathermap.org/examples)\n    * [Sign in](https://openweathermap.org/home/sign_in)\n    * [Support centre](https://openweathermap.org/support-centre)\n\n\n  *   * [Guide](https://openweathermap.org/guide)\n  * [API](https://openweathermap.org/api)\n  * [Marketplace](https://home.openweathermap.org/marketplace)\n  * [Pricing](https://openweathermap.org/price)\n  * [Maps](https://openweathermap.org/weathermap)\n  * [Our Initiatives](https://openweathermap.org/our-initiatives)\n  * [Partners](https://openweathermap.org/examples)\n  * [Support centre](https://openweathermap.org/support-centre)\n  * [Sign in](https://openweathermap.org/home/sign_in)\n\n\n# Global Precipitation Maps\n  1. [Home](https://openweathermap.org/)\n  2. [API](https://openweathermap.org/api)\n  3. Global Precipitation Maps\n\n\n  * [Features of Global Precipitation Map](https://openweathermap.org/api/global-precipitation-map#features)\n  * [URL format and parameters](https://openweathermap.org/api/global-precipitation-map#url)\n  * [Example of Global Precipitation Map layer](https://openweathermap.org/api/global-precipitation-map#example)\n  * [Libraries to connect weather layers](https://openweathermap.org/api/global-precipitation-map#library)\n\n\nGet current and historical global precipitation weather maps via the easy-to-work API. \n## Features of Global Precipitation Map\n  1. Current and historical weather maps\nThe historical weather map for the previous 2 days with a 10 minutes-step.\n  2. Resolution less than 1 km\n  3. Weather map layers: Precipitation layer\n  4. Weather sources\nGlobal Precipitatoin Map is based on global weather models, satellites, radars and our OWM NWP-ML technology.\n  5. There is the [OpenWeather Interactive Weather Maps](https://openweathermap.org/weathermap?basemap=map&cities=true&layer=radar&lat=56.9510&lon=24.1064&zoom=5) with Global Precipitation layer, which provide users with free access to visual data.\n\n\n## URL format and parameters\nUse the following URL format and parameters to get weather maps. Please pay attention to the URL example. \nAPI call\n`                   https://maps.openweathermap.org/maps/2.0/radar/{z}/{x}/{y}?appid=[{API key}](https://home.openweathermap.org/api_keys)&tm={date}                   `\nCopy\n![](https://openweathermap.org/themes/openweathermap/assets/img/documentation/copy.png)\nParameters  \n---  \n`{z}` | required | Number of zoom level.  \nThe minimum value is **3** , and the maximum value is **7**.   \nYou could find information about correlation between zoom levels, X, Y tile coordinate numbers and level scale [here](https://openweathermap.org/faq#zoom_levels)  \n`{x}` | required | Number of x tile coordinate. You could find information about correlation between zoom levels, X, Y tile coordinate numbers and level scale [here](https://openweathermap.org/faq#zoom_levels)  \n`{y}` | required | Number of y tile coordinate. You could find information about correlation between zoom levels, X, Y tile coordinate numbers and level scale [here](https://openweathermap.org/faq#zoom_levels)  \n`appid` | required | Your unique API key (you can always find it on your  ...
#  'https://openweathermap.org/api/hourly-forecast': '![banner android](https://openweathermap.org/themes/openweathermap/assets/img/mobile_app/android-app-top-banner.png)\nOpenWeather\nOpenWeather Ltd.\nGET - on Google Play\n  * [ ![logo](https://openweathermap.org/themes/openweathermap/assets/img/logo_white_cropped.png) ](https://openweathermap.org/)\n  * ![icon hamburger](https://openweathermap.org/themes/openweathermap/assets/img/owm_icons/icon_hamburger.svg)\n  *     * [Guide](https://openweathermap.org/guide)\n    * [API](https://openweathermap.org/api)\n    * [Marketplace](https://home.openweathermap.org/marketplace)\n    * [Pricing](https://openweathermap.org/price)\n    * [Maps](https://openweathermap.org/weathermap)\n    * [Our Initiatives](https://openweathermap.org/our-initiatives)\n    * [Partners](https://openweathermap.org/examples)\n    * [Sign in](https://openweathermap.org/home/sign_in)\n    * [Support centre](https://openweathermap.org/support-centre)\n\n\n  *   * [Guide](https://openweathermap.org/guide)\n  * [API](https://openweathermap.org/api)\n  * [Marketplace](https://home.openweathermap.org/marketplace)\n  * [Pricing](https://openweathermap.org/price)\n  * [Maps](https://openweathermap.org/weathermap)\n  * [Our Initiatives](https://openweathermap.org/our-initiatives)\n  * [Partners](https://openweathermap.org/examples)\n  * [Support centre](https://openweathermap.org/support-centre)\n  * [Sign in](https://openweathermap.org/home/sign_in)\n\n\n# Hourly forecast\n  1. [Home](https://openweathermap.org/)\n  2. [API](https://openweathermap.org/api)\n  3. Hourly forecast\n\n\n  * [Product concept](https://openweathermap.org/api/hourly-forecast#concept)\n  * [Call Hourly forecast data](https://openweathermap.org/api/hourly-forecast#5days)\n    * [How to make an API call](https://openweathermap.org/api/hourly-forecast#geo5)\n  * [API response](https://openweathermap.org/api/hourly-forecast#parameter)\n    * [JSON format API response example](https://openweathermap.org/api/hourly-forecast#example_JSON)\n    * [JSON format API response fields](https://openweathermap.org/api/hourly-forecast#fields_JSON)\n    * [XML format API response example](https://openweathermap.org/api/hourly-forecast#example_XML)\n    * [XML format API response fields](https://openweathermap.org/api/hourly-forecast#fields_XML)\n    * [List of condition codes](https://openweathermap.org/api/hourly-forecast#list)\n    * [Min/max temperature in our weather API](https://openweathermap.org/api/hourly-forecast#min)\n  * [Other features](https://openweathermap.org/api/hourly-forecast#other)\n    * [Geocoding API](https://openweathermap.org/api/hourly-forecast#geocoding)\n    * [Built-in geocoding](https://openweathermap.org/api/hourly-forecast#builtin)\n      * [Built-in API request by city name](https://openweathermap.org/api/hourly-forecast#name5)\n      * [Built-in API request by city ID](https://openweathermap.org/api/hourly-forecast#cityid5)\n      * [Built-in API request by ZIP code](https://openweathermap.org/api/hourly-forecast#zip)\n    * [Format](https://openweathermap.org/api/hourly-forecast#format)\n    * [Limitation of result](https://openweathermap.org/api/hourly-forecast#limit)\n    * [Units of measurement](https://openweathermap.org/api/hourly-forecast#data)\n    * [Multilingual support](https://openweathermap.org/api/hourly-forecast#multi)\n    * [Call back function for JavaScript code](https://openweathermap.org/api/hourly-forecast#call)\n\n\n## Product concept\nHourly forecast for 4 days (96 timestamps). Weather data is available in JSON and XML formats. \n## Call hourly forecast data\n### How to make an API call \nYou can search weather forecast for 4 days with data every hour by geographic coordinates.\nAll weather data can be obtained in JSON and XML formats.\nAPI call\n`https://pro.openweathermap.org/data/2.5/forecast/hourly?lat={lat}&lon={lon}&appid=[{API key}](https://home.openweathermap.org/api_keys)`\nCopy\n![](https://op ...
#  'https://openweathermap.org/api/solar-irradiance': '![banner android](https://openweathermap.org/themes/openweathermap/assets/img/mobile_app/android-app-top-banner.png)\nOpenWeather\nOpenWeather Ltd.\nGET - on Google Play\n  * [ ![logo](https://openweathermap.org/themes/openweathermap/assets/img/logo_white_cropped.png) ](https://openweathermap.org/)\n  * ![icon hamburger](https://openweathermap.org/themes/openweathermap/assets/img/owm_icons/icon_hamburger.svg)\n  *     * [Guide](https://openweathermap.org/guide)\n    * [API](https://openweathermap.org/api)\n    * [Marketplace](https://home.openweathermap.org/marketplace)\n    * [Pricing](https://openweathermap.org/price)\n    * [Maps](https://openweathermap.org/weathermap)\n    * [Our Initiatives](https://openweathermap.org/our-initiatives)\n    * [Partners](https://openweathermap.org/examples)\n    * [Sign in](https://openweathermap.org/home/sign_in)\n    * [Support centre](https://openweathermap.org/support-centre)\n\n\n  *   * [Guide](https://openweathermap.org/guide)\n  * [API](https://openweathermap.org/api)\n  * [Marketplace](https://home.openweathermap.org/marketplace)\n  * [Pricing](https://openweathermap.org/price)\n  * [Maps](https://openweathermap.org/weathermap)\n  * [Our Initiatives](https://openweathermap.org/our-initiatives)\n  * [Partners](https://openweathermap.org/examples)\n  * [Support centre](https://openweathermap.org/support-centre)\n  * [Sign in](https://openweathermap.org/home/sign_in)\n\n\n# Solar Irradiance API\n  1. [Home](https://openweathermap.org/)\n  2. [API](https://openweathermap.org/api)\n  3. Solar Irradiance API\n\n\n  * [Product concept](https://openweathermap.org/api/solar-irradiance#concept)\n  * [How to get access](https://openweathermap.org/api/solar-irradiance#how)\n  * [Call Solar Irradiance data](https://openweathermap.org/api/solar-irradiance#irradiancedata)\n    * [How to make an API call](https://openweathermap.org/api/solar-irradiance#interval_api)\n    * [Example of API call](https://openweathermap.org/api/solar-irradiance#interval_descr)\n    * [Example of API response](https://openweathermap.org/api/solar-irradiance#interval_example)\n    * [Fields in API response](https://openweathermap.org/api/solar-irradiance#interval_fields)\n  * [Bulk downloading](https://openweathermap.org/api/solar-irradiance#bulk)\n  * [API errors](https://openweathermap.org/api/solar-irradiance#errors)\n    * [Strucure of API errors](https://openweathermap.org/api/solar-irradiance#errorstructure)\n    * [Errors list](https://openweathermap.org/api/solar-irradiance#popularerrors)\n      * [Error 400](https://openweathermap.org/api/solar-irradiance#error400)\n      * [Error 401](https://openweathermap.org/api/solar-irradiance#error401)\n      * [Error 404](https://openweathermap.org/api/solar-irradiance#error404)\n      * [Error 429](https://openweathermap.org/api/solar-irradiance#error429)\n      * [Errors \'5xx\'](https://openweathermap.org/api/solar-irradiance#error500)\n  * [Solar Irradiance technology](https://openweathermap.org/api/solar-radiation/behind-solar-radiation-api)\n\n\n✔**This is the latest version of the API (v2).**\n[ Looking for the previous version? You can find the v1 documentation here. ](https://openweathermap.org/api/solar-energy-prediction)\n## Product concept\n**Solar Irradiance** service supplies accurate solar irradiance data for any location on the globe.\nMain features of Solar Irradiance API:\n  * Essential solar irradiation data: \n    * [Global Horizontal Irradiation (GHI)](https://openweathermap.org/api/solar-radiation/behind-solar-radiation-api#introduction)\n    * [Direct Normal Irradiation (DNI)](https://openweathermap.org/api/solar-radiation/behind-solar-radiation-api#introduction)\n    * [Diffuse Horizontal Irradiation (DHI)](https://openweathermap.org/api/solar-radiation/behind-solar-radiation-api#introduction)\n  * All indices are available in [Clear Sky](https://openweathermap.org/api/solar-radiation/behind-s ...
# ...
#  'https://home.openweathermap.org/api_keys': "  * [![Logo white](https://home.openweathermap.org/assets/logo_white-12c4f864cc825cfead13b43f6fdae14172bb7848529cb9f48374b9ebb0e9f061.png) ](https://openweathermap.org)\n  * ![Icon hamburger](https://home.openweathermap.org/assets/icon_hamburger-397ca8b59f43c4c36ead3dd7e00891c3db04b47e83e72a56efbfe522a13cd656.svg)\n    * [Guide](https://openweathermap.org/guide)\n    * [API](https://openweathermap.org/api)\n    * [Dashboard](https://openweathermap.org/weather-dashboard)\n    * [Marketplace](https://home.openweathermap.org/marketplace)\n    * [Pricing](https://openweathermap.org/price)\n    * [Maps](https://openweathermap.org/weathermap)\n    * [Our Initiatives](https://openweathermap.org/our-initiatives)\n    * [Partners](https://openweathermap.org/examples)\n    * [Sign In ](https://home.openweathermap.org/users/sign_in)\n    * Support \n      * [FAQ](https://openweathermap.org/faq)\n      * [How to start](https://openweathermap.org/appid)\n      * [ChatBot assistant](https://openweathermap.org/chat)\n      * [Ask a question](https://home.openweathermap.org/questions)\n\n\n  *   * [Guide](https://openweathermap.org/guide)\n  * [API](https://openweathermap.org/api)\n  * [Dashboard](https://openweathermap.org/weather-dashboard)\n  * [Marketplace](https://home.openweathermap.org/marketplace)\n  * [Pricing](https://openweathermap.org/price)\n  * [Maps](https://openweathermap.org/weathermap)\n  * [Our Initiatives](https://openweathermap.org/our-initiatives)\n  * [Partners](https://openweathermap.org/examples)\n  * [Ask a question](https://home.openweathermap.org/questions)\n  * [Sign In ](https://home.openweathermap.org/users/sign_in)\n\n\nAlert\nYou need to sign in or sign up before continuing.\n### Sign In To Your Account\n* * *\n  \n\nRemember me\n* * *\nNot registered? [Create an Account.](https://home.openweathermap.org/users/sign_up)\nLost your password? [Click here to recover.](https://home.openweathermap.org/users/sign_in)\nEnter your email address and we will send you a link to reset your password.\nEmail\nProduct Collections\n  * [Current and Forecast APIs](https://openweathermap.org/api#current)\n  * [Historical Weather Data](https://openweathermap.org/api#history)\n  * [Weather Maps](https://openweathermap.org/api#maps)\n  * [Weather Dashboard](https://openweathermap.org/weather-dashboard)\n  * [Widgets](https://openweathermap.org/widgets-constructor)\n\n\nSubscription\n  * [How to start](https://openweathermap.org/appid)\n  * [Pricing](https://openweathermap.org/price)\n  * [Subscribe for free](https://home.openweathermap.org/users/sign_up)\n  * [FAQ](https://openweathermap.org/faq)\n\n\nCompany \nOpenWeather is a team of IT experts and data scientists that has been practising deep weather data science since 2014. For each point on the globe, OpenWeather provides historical, current and forecasted weather data via light-speed APIs. Headquarters in London, UK. \nTechnologies\n  * [Our technology](https://openweathermap.org/technology)\n  * [Accuracy and quality of weather data](https://openweathermap.org/accuracy-and-quality)\n  * [Connect your weather station](https://openweathermap.org/stations)\n\n\nTerms & Conditions\nContact us\n  * [About us](https://openweathermap.org/about-us)\n  * [ChatBot assistant](https://openweathermap.org/chat)\n  * [Ask a question](https://home.openweathermap.org/questions)\n\n\nDownload OpenWeather app\n!['RMets logo](https://home.openweathermap.org/assets/rmets1-ecdd2213e5da558489a4f673a36c2daa0ef8cf091ea5b37eee7d11429ab1406c.png)\nSupplier of Achilles UVDB community   \n© 2012 — 2025 OpenWeather ® All rights reserved   \n  \n\n**Please wait...**\n",
#  'https://openweathermap.org/api/solar-energy-prediction': '![banner android](https://openweathermap.org/themes/openweathermap/assets/img/mobile_app/android-app-top-banner.png)\nOpenWeather\nOpenWeather Ltd.\nGET - on Google Play\n  * [ ![logo](https://openweathermap.org/themes/openweathermap/assets/img/logo_white_cropped.png) ](https://openweathermap.org/)\n  * ![icon hamburger](https://openweathermap.org/themes/openweathermap/assets/img/owm_icons/icon_hamburger.svg)\n  *     * [Guide](https://openweathermap.org/guide)\n    * [API](https://openweathermap.org/api)\n    * [Marketplace](https://home.openweathermap.org/marketplace)\n    * [Pricing](https://openweathermap.org/price)\n    * [Maps](https://openweathermap.org/weathermap)\n    * [Our Initiatives](https://openweathermap.org/our-initiatives)\n    * [Partners](https://openweathermap.org/examples)\n    * [Sign in](https://openweathermap.org/home/sign_in)\n    * [Support centre](https://openweathermap.org/support-centre)\n\n\n  *   * [Guide](https://openweathermap.org/guide)\n  * [API](https://openweathermap.org/api)\n  * [Marketplace](https://home.openweathermap.org/marketplace)\n  * [Pricing](https://openweathermap.org/price)\n  * [Maps](https://openweathermap.org/weathermap)\n  * [Our Initiatives](https://openweathermap.org/our-initiatives)\n  * [Partners](https://openweathermap.org/examples)\n  * [Support centre](https://openweathermap.org/support-centre)\n  * [Sign in](https://openweathermap.org/home/sign_in)\n\n\n# Solar Irradiance API v1\n  1. [Home](https://openweathermap.org/)\n  2. [API](https://openweathermap.org/api)\n  3. Solar Irradiance API v1\n\n\n  * [Product concept](https://openweathermap.org/api/solar-energy-prediction#concept)\n  * [How to get access ](https://openweathermap.org/api/solar-energy-prediction#how)\n  * [Route 1: daily aggregation with detalization by 15-min and 1-hour intervals](https://openweathermap.org/api/solar-energy-prediction#route1)\n    * [How to make an API call](https://openweathermap.org/api/solar-energy-prediction#interval_api)\n    * [Example of API call](https://openweathermap.org/api/solar-energy-prediction#api3)\n    * [Example of API response](https://openweathermap.org/api/solar-energy-prediction#interval_example)\n    * [Fields in API response](https://openweathermap.org/api/solar-energy-prediction#interval_fields)\n  * [Route 2: daily aggregation with hourly detalization](https://openweathermap.org/api/solar-energy-prediction#route2)\n    * [How to make an API call](https://openweathermap.org/api/solar-energy-prediction#api)\n    * [Example of API call](https://openweathermap.org/api/solar-energy-prediction#api2)\n    * [Example of API response](https://openweathermap.org/api/solar-energy-prediction#example)\n    * [Fields in API response](https://openweathermap.org/api/solar-energy-prediction#fields)\n  * [Bulk downloading](https://openweathermap.org/api/solar-energy-prediction#bulk)\n  * [API errors](https://openweathermap.org/api/solar-energy-prediction#errors)\n    * [Strucure of API errors](https://openweathermap.org/api/solar-energy-prediction#errorstructure)\n    * [Errors list](https://openweathermap.org/api/solar-energy-prediction#popularerrors)\n      * [Error 400](https://openweathermap.org/api/solar-energy-prediction#error400)\n      * [Error 401](https://openweathermap.org/api/solar-energy-prediction#error401)\n      * [Error 404](https://openweathermap.org/api/solar-energy-prediction#error404)\n      * [Error 429](https://openweathermap.org/api/solar-energy-prediction#error429)\n      * [Errors \'5xx\'](https://openweathermap.org/api/solar-energy-prediction#error500)\n  * [Solar Irradiance technology](https://openweathermap.org/api/solar-radiation/behind-solar-radiation-api)\n\n\n⚠️ [ You are viewing an outdated version of the API. The current version is available here. ](https://openweathermap.org/api/solar-irradiance)\n## Product concept\n**Solar Irradiance & Energy Prediction** service helps to predic ...
#  'https://openweathermap.org/api/solar-radiation/behind-solar-radiation-api': '![banner android](https://openweathermap.org/themes/openweathermap/assets/img/mobile_app/android-app-top-banner.png)\nOpenWeather\nOpenWeather Ltd.\nGET - on Google Play\n  * [ ![logo](https://openweathermap.org/themes/openweathermap/assets/img/logo_white_cropped.png) ](https://openweathermap.org/)\n  * ![icon hamburger](https://openweathermap.org/themes/openweathermap/assets/img/owm_icons/icon_hamburger.svg)\n  *     * [Guide](https://openweathermap.org/guide)\n    * [API](https://openweathermap.org/api)\n    * [Marketplace](https://home.openweathermap.org/marketplace)\n    * [Pricing](https://openweathermap.org/price)\n    * [Maps](https://openweathermap.org/weathermap)\n    * [Our Initiatives](https://openweathermap.org/our-initiatives)\n    * [Partners](https://openweathermap.org/examples)\n    * [Sign in](https://openweathermap.org/home/sign_in)\n    * [Support centre](https://openweathermap.org/support-centre)\n\n\n  *   * [Guide](https://openweathermap.org/guide)\n  * [API](https://openweathermap.org/api)\n  * [Marketplace](https://home.openweathermap.org/marketplace)\n  * [Pricing](https://openweathermap.org/price)\n  * [Maps](https://openweathermap.org/weathermap)\n  * [Our Initiatives](https://openweathermap.org/our-initiatives)\n  * [Partners](https://openweathermap.org/examples)\n  * [Support centre](https://openweathermap.org/support-centre)\n  * [Sign in](https://openweathermap.org/home/sign_in)\n\n\n# Solar Irradiance technology\n  1. [Home](https://openweathermap.org/)\n  2. [Solar Irradiance API](https://openweathermap.org/api/solar-irradiance)\n  3. Solar Irradiance technology\n\n\n  * [Introduction to Solar Irradiance technology](https://openweathermap.org/api/solar-radiation/behind-solar-radiation-api#introduction)\n  * [OpenWeather Clear Sky model](https://openweathermap.org/api/solar-radiation/behind-solar-radiation-api#clearsky)\n  * [OpenWeather Cloudy Sky model](https://openweathermap.org/api/solar-radiation/behind-solar-radiation-api#cloudysky)\n  * [Reference data for solar radiation model experiments](https://openweathermap.org/api/solar-radiation/behind-solar-radiation-api#reference)\n  * [Technical documentation of Solar Irradiance API](https://openweathermap.org/api/solar-irradiance)\n\n\n## Introduction\nConsidering the importance of ecology and the search for renewable energy sources in the modern world, our company has decided to make a contribution to this cause. We wanted to give all our users an opportunity to get valuable data easily, regardless of the size of their projects. \nAlthough [Solar Irradiance ](https://openweathermap.org/api/solar-irradiance) & [Energy Prediction ](https://openweathermap.org/api/solar-panels-and-energy-prediction-2) service was created on the basis of a large number of scientific articles, algorithms, models and data sources, we wanted, as always, to ensure that our final product is as versatile and easy to use as possible. \nThe basic definitions of solar power sector are solar irradiation and solar irradiance and are often used interchangeably. However, they are not a synonyms:\n  * **Solar irradiation** is the total energy received by a surface of the Earth per unit area over a given period of time. It is the amount of radiation (also known as shortwave radiation) passing through a horizontal plane. Solar irradiance is measured in Wh/m2.\n  * **Solar irradiance** is the surface power density received by a surface of the Earth. Solar irradiance is measured in W/m2. \n\n\nTo convert irradiance to irradiation please use the formula below:\n**Energy(Wh/m 2) = Power(W/m2) * TimeInterval(h)**\nwhere energy is a solar irradiation; power is a solar irradiance.\nFor energy data values for 1 h period of TimeInterval = 1\nFor energy data values for 15 min period of TimeInterval = 0.25\nAt the first stage of product development, we have selected the most common indices for solar irradiation m ...
#  'https://openweathermap.org/api/solar-panels-and-energy-prediction': '![banner android](https://openweathermap.org/themes/openweathermap/assets/img/mobile_app/android-app-top-banner.png)\nOpenWeather\nOpenWeather Ltd.\nGET - on Google Play\n  * [ ![logo](https://openweathermap.org/themes/openweathermap/assets/img/logo_white_cropped.png) ](https://openweathermap.org/)\n  * ![icon hamburger](https://openweathermap.org/themes/openweathermap/assets/img/owm_icons/icon_hamburger.svg)\n  *     * [Guide](https://openweathermap.org/guide)\n    * [API](https://openweathermap.org/api)\n    * [Marketplace](https://home.openweathermap.org/marketplace)\n    * [Pricing](https://openweathermap.org/price)\n    * [Maps](https://openweathermap.org/weathermap)\n    * [Our Initiatives](https://openweathermap.org/our-initiatives)\n    * [Partners](https://openweathermap.org/examples)\n    * [Sign in](https://openweathermap.org/home/sign_in)\n    * [Support centre](https://openweathermap.org/support-centre)\n\n\n  *   * [Guide](https://openweathermap.org/guide)\n  * [API](https://openweathermap.org/api)\n  * [Marketplace](https://home.openweathermap.org/marketplace)\n  * [Pricing](https://openweathermap.org/price)\n  * [Maps](https://openweathermap.org/weathermap)\n  * [Our Initiatives](https://openweathermap.org/our-initiatives)\n  * [Partners](https://openweathermap.org/examples)\n  * [Support centre](https://openweathermap.org/support-centre)\n  * [Sign in](https://openweathermap.org/home/sign_in)\n\n\n# Solar Panel Energy Prediction v1\n  1. [Home](https://openweathermap.org/)\n  2. [API](https://openweathermap.org/api)\n  3. Solar Panel Energy Prediction v1\n\n\n  * [Product concept](https://openweathermap.org/api/solar-panels-and-energy-prediction#concept)\n  * [How to use the service](https://openweathermap.org/api/solar-panels-and-energy-prediction#how)\n  * [Step 1: Manage my location](https://openweathermap.org/api/solar-panels-and-energy-prediction#step1)\n    * [How to create a unique location](https://openweathermap.org/api/solar-panels-and-energy-prediction#post_location)\n    * [How to get a location data](https://openweathermap.org/api/solar-panels-and-energy-prediction#get_location)\n    * [How to get a list of created locations](https://openweathermap.org/api/solar-panels-and-energy-prediction#get_all_locations)\n    * [How to delete a location](https://openweathermap.org/api/solar-panels-and-energy-prediction#delete_location)\n  * [Step 2: Operations with solar panels](https://openweathermap.org/api/solar-panels-and-energy-prediction#step2)\n    * [How to create a solar panel](https://openweathermap.org/api/solar-panels-and-energy-prediction#post_panel)\n    * [How to get a solar panel data](https://openweathermap.org/api/solar-panels-and-energy-prediction#get_panel)\n    * [How to get a list of created solar panels](https://openweathermap.org/api/solar-panels-and-energy-prediction#get_all_panels)\n    * [How to delete a solar panel](https://openweathermap.org/api/solar-panels-and-energy-prediction#delete_panel)\n  * [Step 3: Get solar panel power output and solar irradiation data by location](https://openweathermap.org/api/solar-panels-and-energy-prediction#step3)\n    * [Route 1: daily aggregation with hourly detalization](https://openweathermap.org/api/solar-panels-and-energy-prediction#route1)\n      * [How to make an API call](https://openweathermap.org/api/solar-panels-and-energy-prediction#route1paneloutputapi)\n      * [Example of API response](https://openweathermap.org/api/solar-panels-and-energy-prediction#route1paneloutputexample)\n      * [Fields in API response](https://openweathermap.org/api/solar-panels-and-energy-prediction#route1paneloutputfields)\n    * [Route 2: daily aggregation with detalization by intervals](https://openweathermap.org/api/solar-panels-and-energy-prediction#route2)\n      * [How to make an API call](https://openweathermap.org/api/solar-panels-and-energy-prediction#route2paneloutputapi)\n     ...

# %%
# analyzer = DocumentAnalyzer(max_workers=10)
# doc_analysis = analyzer.analyze(crawl4ai_contents)

# import pickle
# with open('doc-analysis.pkl', 'wb') as f:
#     pickle.dump(doc_analysis, f)

# %%
import pickle
with open('doc-analysis.pkl', 'rb') as f:
    doc_analysis = pickle.load(f)

# %%
import dspy
from test_plan import PageTestPlanExtractor, TestPlanConsolidator, DEFAULT_TEST_PLAN_INSTRUCTIONS

page_extractor = dspy.ChainOfThought(PageTestPlanExtractor)
# consolidator = dspy.ChainOfThought(TestPlanConsolidator)

# %%
def process_page(page, analysis):
    page_test_plan = page_extractor(
        page_url=page,
        page_analysis=analysis.model_dump_json(),
        raw_content=doc_analysis.pages[page].content,
        agent_instructions=DEFAULT_TEST_PLAN_INSTRUCTIONS
    )
    return page_test_plan

# %%
page_test_plans = []
with ThreadPoolExecutor(max_workers=15) as executor:
    # Submit all tasks
    future_to_page = {executor.submit(process_page, page, analysis): (page, analysis) 
                      for page, analysis in doc_analysis.pages.items()}
    
    # Collect results as they complete
    for future in as_completed(future_to_page):
        page, analysis = future_to_page[future]
        try:
            page_test_plan = future.result()
            page_test_plans.append((page, analysis, page_test_plan))
        except Exception as exc:
            print(f'Page {page} generated an exception: {exc}')

# %%
page_index = 4
page_url = page_test_plans[page_index][0]
page_analysis = page_test_plans[page_index][1]
page_test_plan = page_test_plans[page_index][2]
page_content = page_analysis.model_dump()['content']
page_test_scenarios = page_test_plan.test_scenarios
test_scenario = page_test_scenarios[1].model_dump_json()

# %%
import dspy
import subprocess
import sys
import time
import traceback
from typing import Dict, Any, List
from enum import Enum
from pydantic import BaseModel, Field
import json
import os

class TestStatus(Enum):
    PASSED = "PASSED"
    MINOR_FAILURE = "MINOR_FAILURE"
    MAJOR_FAILURE = "MAJOR_FAILURE"

class TestResult(BaseModel):
    """Enhanced test execution result with generic tracking"""
    scenario_name: str
    passed: TestStatus = Field(description="Minor failure if the test passed but there were some minor issues, major failure if the test failed")
    execution_time: float

    # Enhanced tracking - GENERIC for all tool types
    trajectory: Any
    final_reasoning: str = ""  # Agent's final reasoning

def extract_code(code_string: str) -> str:
    """Extract clean Python code from markdown-wrapped code string"""
    if code_string.startswith("'") and code_string.endswith("'"):
        code_string = code_string[1:-1]
    
    if code_string.startswith('```python'):
        code_string = code_string[9:]
    elif code_string.startswith('```'):
        code_string = code_string[3:]
    
    if code_string.endswith('```'):
        code_string = code_string[:-3]
    
    code_string = code_string.replace('\\n', '\n')
    return code_string.strip()

# Global context storage
_global_context = {}

# Global storage for detailed tracking
_execution_details = {
    'code_generated': [],
    'tool_results': [],
    'detected_patterns': [],  # Generic patterns instead of HTTP-specific
    'execution_success': False,
    'status_success': False,  # Generic status success (not just HTTP)
    'assertion_success': False,
    'pattern_success': False  # Based on success/failure indicators
}

def reset_execution_details():
    """Reset tracking for new test"""
    global _execution_details
    _execution_details = {
        'code_generated': [],
        'tool_results': [],
        'detected_patterns': [],
        'execution_success': False,
        'status_success': False,
        'assertion_success': False,
        'pattern_success': False
    }

def set_global_context(context: dict):
    """Set global context for tools to access"""
    global _global_context
    _global_context = context.copy() if context else {}

def set_environment_variables_direct(context: dict):
    """Set environment variables directly from context keys"""
    for env_key, value in context.items():
        if value:
            os.environ[env_key] = str(value)
            print(f"Set {env_key} = {str(value)[:8]}***")

# DSPy ReAct Tools - these need simple signatures
def check_available_api_keys():
    """Check what API keys are available in the context"""
    context = _global_context
    
    if not context:
        return "⚠️  NO CONTEXT PROVIDED - No API keys available"
    
    available_keys = []
    for key, value in context.items():
        if value:  # Only show keys that have values
            masked_value = str(value)[:8] + "***" if len(str(value)) > 8 else "***"
            available_keys.append(f"✅ {key}: {masked_value}")
    
    if available_keys:
        result = "🔑 AVAILABLE API KEYS:\n\n"
        result += "\n".join(available_keys) + "\n\n"
        result += "💡 Use os.getenv('KEY_NAME') to access these in your code\n"
        result += f"Available keys: {', '.join(context.keys())}"
    else:
        result = "⚠️  NO API KEYS IN CONTEXT!"
    
    return result

def execute_code(code: str):
    """Execute Python code with environment variables from global context"""
    context = _global_context
    start_time = time.time()
    
    try:
        # Clean the code first
        clean_code = extract_code(code)
        
        # Set environment variables directly from context
        if context:
            set_environment_variables_direct(context)
        
        # Basic execution environment
        exec_globals = {
            '__builtins__': __builtins__,
            'time': time,
            'json': json,
            'subprocess': subprocess,
            'sys': sys,
        }
        
        # Capture output
        captured_output = []
        
        def capture_print(*args, **kwargs):
            line = ' '.join(str(arg) for arg in args)
            captured_output.append(line)
            print(line)  # Still print to console
        
        exec_globals['print'] = capture_print
        
        # Execute the code
        exec(clean_code, exec_globals)
        
        execution_time = time.time() - start_time
        output = '\n'.join(captured_output) if captured_output else "Code executed successfully (no output)"
        
        return f"SUCCESS: Code executed in {execution_time:.2f}s\nOutput:\n{output}"
        
    except ImportError as e:
        execution_time = time.time() - start_time
        missing_module = str(e).split("'")[1] if "'" in str(e) else str(e)
        return f"MISSING_DEPENDENCY: {missing_module}\nError: {str(e)}\nTime: {execution_time:.2f}s"
        
    except Exception as e:
        execution_time = time.time() - start_time
        error_trace = traceback.format_exc()
        return f"ERROR: Code execution failed in {execution_time:.2f}s\nError: {str(e)}\nTrace:\n{error_trace}"

def install_package(package_name: str):
    """Try to install a Python package with tracking"""
    global _execution_details
    
    try:
        print(f"Attempting to install {package_name}...")
        result = subprocess.run(
            [sys.executable, '-m', 'pip', 'install', package_name],
            capture_output=True,
            text=True,
            timeout=60
        )
        
        success = result.returncode == 0
        tool_result = {
            'tool': 'install_package',
            'package': package_name,
            'success': success,
            'return_code': result.returncode
        }
        _execution_details['tool_results'].append(tool_result)
        
        if success:
            return f"Successfully installed {package_name}"
        else:
            return f"Failed to install {package_name}: {result.stderr}"
            
    except Exception as e:
        tool_result = {
            'tool': 'install_package',
            'package': package_name,
            'success': False,
            'error': str(e)
        }
        _execution_details['tool_results'].append(tool_result)
        return f"Installation error: {str(e)}"

def check_environment():
    """Check what packages are available with tracking"""
    global _execution_details
    
    try:
        result = subprocess.run(
            [sys.executable, '-m', 'pip', 'list'],
            capture_output=True,
            text=True,
            timeout=30
        )
        
        tool_result = {
            'tool': 'check_environment',
            'success': result.returncode == 0,
            'package_count': len(result.stdout.split('\n')) if result.stdout else 0
        }
        _execution_details['tool_results'].append(tool_result)
        
        return f"Environment check completed. Installed packages:\n{result.stdout[:500]}..."
        
    except Exception as e:
        tool_result = {
            'tool': 'check_environment',
            'success': False,
            'error': str(e)
        }
        _execution_details['tool_results'].append(tool_result)
        return f"Environment check failed: {str(e)}"

def check_available_api_keys():
    """Check what API keys are available with tracking"""
    global _execution_details
    context = _global_context
    
    if not context:
        tool_result = {
            'tool': 'check_available_api_keys',
            'success': False,
            'key_count': 0
        }
        _execution_details['tool_results'].append(tool_result)
        return "⚠️  NO CONTEXT PROVIDED - No API keys available"
    
    available_keys = []
    for key, value in context.items():
        if value:  # Only show keys that have values
            masked_value = str(value)[:8] + "***" if len(str(value)) > 8 else "***"
            available_keys.append(f"✅ {key}: {masked_value}")
    
    tool_result = {
        'tool': 'check_available_api_keys',
        'success': len(available_keys) > 0,
        'key_count': len(available_keys),
        'keys': list(context.keys())
    }
    _execution_details['tool_results'].append(tool_result)
    
    if available_keys:
        result = "🔑 AVAILABLE API KEYS:\n\n"
        result += "\n".join(available_keys) + "\n\n"
        result += "💡 Use os.getenv('KEY_NAME') to access these in your code\n"
        result += f"Available keys: {', '.join(context.keys())}"
    else:
        result = "⚠️  NO API KEYS IN CONTEXT!"
    
    return result

class TestExecutorSignature(dspy.Signature):
    """You are a test execution agent that runs test scenarios for developer tools.
    
    You can execute code, install dependencies, check the environment, and check available API keys.
    Your goal is to successfully execute the test scenario and determine if it PASSED, MINOR_FAILURE, or MAJOR_FAILURE.

    CLASSIFICATION CRITERIA:
    
    PASSED: 
    - Test scenario executed successfully without any issues
    - All assertions passed as expected
    - No code modifications or workarounds were needed
    - API responses matched expected format exactly
    
    MINOR_FAILURE: 
    - Test scenario succeeded but required workarounds or adjustments
    - API responses were in different format than expected (but still valid)
    - Had to modify test logic due to documentation inconsistencies  
    - Missing dependencies that were easily installable
    - Minor authentication or configuration issues that were resolved
    - Expected format didn't match actual API behavior
    
    MAJOR_FAILURE:
    - Test scenario completely failed to execute
    - Authentication failed and couldn't be resolved
    - Critical dependencies missing and couldn't be installed
    - API endpoints don't exist or are completely non-functional
    - Code errors that couldn't be resolved
    
    Available tools:
    - check_available_api_keys(): See what API keys are available
    - execute_code(code): Run Python code 
    - install_package(name): Install missing packages
    - check_environment(): List installed packages
    
    IMPORTANT: If you need to modify test expectations or make workarounds due to 
    documentation inconsistencies, classify as MINOR_FAILURE, not PASSED.
    """
    
    scenario: str = dspy.InputField(desc="JSON string of the test scenario to execute")
    context: str = dspy.InputField(desc="JSON string of context with API keys and configurations")
    
    execution_result: str = dspy.OutputField(desc="Final result: PASSED, MINOR_FAILURE, or MAJOR_FAILURE with explanation")

# Create the ReAct agent
test_executor_agent = dspy.ReAct(
    TestExecutorSignature,
    tools=[
        check_available_api_keys,
        execute_code,
        install_package, 
        check_environment
    ],
    max_iters=10
)

def run_test_with_react(scenario, page_content: str, context: Dict[str, str] = None) -> TestResult:
    """Run a test scenario using the ReAct agent"""
    context = context or {}
    start_time = time.time()
    
    try:
        # Set global context for tools to access
        set_global_context(context)
        
        # Run the ReAct agent
        result = test_executor_agent(
            scenario=scenario.model_dump_json(),
            context=json.dumps(page_content)
        )
        
        print("=== REACT AGENT RESULT ===")
        print(f"Execution Result: {result.execution_result}")
        if hasattr(result, 'reasoning'):
            print(f"Reasoning: {result.reasoning}")
        
        # Parse the result
        if "PASSED" in result.execution_result.upper():
            passed = TestStatus.PASSED
        elif "MINOR_FAILURE" in result.execution_result.upper():
            passed = TestStatus.MINOR_FAILURE
        elif "MAJOR_FAILURE" in result.execution_result.upper():
            passed = TestStatus.MAJOR_FAILURE
        else:
            passed = TestStatus.MAJOR_FAILURE  # Default to MAJOR_FAILURE if unknown
        

        reasoning = ""
        if hasattr(result, 'reasoning'):
            reasoning = result.reasoning
            print(f"Reasoning: {reasoning}")
        
        # Extract steps from trajectory
        steps = []
        if hasattr(result, 'trajectory'):
            for i in range(20):  # Check up to 20 steps
                thought_key = f'thought_{i}'
                tool_key = f'tool_name_{i}'
                if thought_key in result.trajectory and tool_key in result.trajectory:
                    thought = result.trajectory[thought_key]
                    tool = result.trajectory[tool_key]
                    steps.append(f"Step {i+1}: {thought} -> Used {tool}")
                else:
                    break
        
        return TestResult(
            scenario_name=scenario.name,
            passed=passed,
            execution_time=time.time() - start_time,
            trajectory=result.trajectory,
            final_reasoning=reasoning
        )
        
    except Exception as e:
        print(f"ERROR in run_test_with_react_enhanced: {str(e)}")
        traceback.print_exc()
        return TestResult(
            scenario_name=scenario.name,
            passed=TestStatus.MAJOR_FAILURE,
            execution_time=time.time() - start_time,
            output="",
            error_message=f"ReAct agent error: {str(e)}",
            steps_taken=["Agent execution failed"],
            code_generated=[],
            code_execution_output=[],
        )

# %%
context = {
    "OPEN_WEATHER_API_KEY": "7a4834a9d4b666e30261978ec5950ab6"
}

page_index = 1
page_url = page_test_plans[page_index][0]
page_analysis = page_test_plans[page_index][1]
page_test_plan = page_test_plans[page_index][2]
page_content = page_analysis.model_dump()['content']
page_test_scenarios = page_test_plan.test_scenarios


results = []
for page_test_scenario in page_test_scenarios:
    result = run_test_with_react(
        page_test_scenario, 
        page_content,
        context
    )
    results.append(result)
# Out:
# Attempting to install selenium...
# Attempting to install undetected_chromedriver...
# Set OPEN_WEATHER_API_KEY = 7a4834a9***
# Error: OPENWEATHER_USERNAME and OPENWEATHER_PASSWORD environment variables must be set.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[110], line 15
#      13 results = []
#      14 for page_test_scenario in page_test_scenarios:
# ---> 15     result = run_test_with_react(
#      16         page_test_scenario,
#      17         page_content,
#      18         context
#      19     )
#      20     results.append(result)
#
# Cell In[105], line 328, in run_test_with_react(scenario, page_content, context)
#     325 set_global_context(context)
#     327 # Run the ReAct agent
# --> 328 result = test_executor_agent(
#     329     scenario=scenario.model_dump_json(),
#     330     context=json.dumps(page_content)
#     331 )
#     333 print("=== REACT AGENT RESULT ===")
#     334 print(f"Execution Result: {result.execution_result}")
#
# File ~/miniforge3/lib/python3.11/site-packages/dspy/utils/callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     324 callbacks = _get_active_callbacks(instance)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#     330 _execute_start_callbacks(instance, fn, call_id, callbacks, args, kwargs)
#
# File ~/miniforge3/lib/python3.11/site-packages/dspy/primitives/program.py:60, in Module.__call__(self, *args, **kwargs)
#      57     output.set_lm_usage(usage_tracker.get_total_tokens())
#      58     return output
# ---> 60 return self.forward(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.11/site-packages/dspy/predict/react.py:79, in ReAct.forward(self, **input_args)
#      77 for idx in range(max_iters):
#      78     try:
# ---> 79         pred = self._call_with_potential_trajectory_truncation(self.react, trajectory, **input_args)
#      80     except ValueError as err:
#      81         logger.warning(f"Ending the trajectory: Agent failed to select a valid tool: {_fmt_exc(err)}")
#
# File ~/miniforge3/lib/python3.11/site-packages/dspy/predict/react.py:127, in ReAct._call_with_potential_trajectory_truncation(self, module, trajectory, **input_args)
#     125 for _ in range(3):
#     126     try:
# --> 127         return module(
#     128             **input_args,
#     129             trajectory=self._format_trajectory(trajectory),
#     130         )
#     131     except ContextWindowExceededError:
#     132         logger.warning("Trajectory exceeded the context window, truncating the oldest tool call information.")
#
# File ~/miniforge3/lib/python3.11/site-packages/dspy/predict/predict.py:85, in Predict.__call__(self, *args, **kwargs)
#      82 if args:
#      83     raise ValueError(self._get_positional_args_error_message())
# ---> 85 return super().__call__(**kwargs)
#
# File ~/miniforge3/lib/python3.11/site-packages/dspy/utils/callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     324 callbacks = _get_active_callbacks(instance)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#     330 _execute_start_callbacks(instance, fn, call_id, callbacks, args, kwargs)
#
# File ~/miniforge3/lib/python3.11/site-packages/dspy/primitives/program.py:60, in Module.__call__(self, *args, **kwargs)
#      57     output.set_lm_usage(usage_tracker.get_total_tokens())
#      58     return output
# ---> 60 return self.forward(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.11/site-packages/dspy/predict/predict.py:157, in Predict.forward(self, **kwargs)
#     155 else:
#     156     with settings.context(send_stream=None):
# --> 157         completions = adapter(lm, lm_kwargs=config, signature=signature, demos=demos, inputs=kwargs)
#     159 return self._forward_postprocess(completions, signature, **kwargs)
#
# File ~/miniforge3/lib/python3.11/site-packages/dspy/adapters/chat_adapter.py:42, in ChatAdapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#      33 def __call__(
#      34     self,
#      35     lm: LM,
#    (...)     39     inputs: dict[str, Any],
#      40 ) -> list[dict[str, Any]]:
#      41     try:
# ---> 42         return super().__call__(lm, lm_kwargs, signature, demos, inputs)
#      43     except Exception as e:
#      44         # fallback to JSONAdapter
#      45         from dspy.adapters.json_adapter import JSONAdapter
#
# File ~/miniforge3/lib/python3.11/site-packages/dspy/adapters/base.py:119, in Adapter.__call__(self, lm, lm_kwargs, signature, demos, inputs)
#     116 processed_signature = self._call_preprocess(lm, lm_kwargs, signature, inputs)
#     117 inputs = self.format(processed_signature, demos, inputs)
# --> 119 outputs = lm(messages=inputs, **lm_kwargs)
#     120 return self._call_postprocess(signature, outputs)
#
# File ~/miniforge3/lib/python3.11/site-packages/dspy/utils/callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     324 callbacks = _get_active_callbacks(instance)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#     330 _execute_start_callbacks(instance, fn, call_id, callbacks, args, kwargs)
#
# File ~/miniforge3/lib/python3.11/site-packages/dspy/clients/base_lm.py:96, in BaseLM.__call__(self, prompt, messages, **kwargs)
#      94 @with_callbacks
#      95 def __call__(self, prompt=None, messages=None, **kwargs):
# ---> 96     response = self.forward(prompt=prompt, messages=messages, **kwargs)
#      97     outputs = self._process_lm_response(response, prompt, messages, **kwargs)
#      99     return outputs
#
# File ~/miniforge3/lib/python3.11/site-packages/dspy/clients/lm.py:127, in LM.forward(self, prompt, messages, **kwargs)
#     124 completion = litellm_completion if self.model_type == "chat" else litellm_text_completion
#     125 completion, litellm_cache_args = self._get_cached_completion_fn(completion, cache, enable_memory_cache)
# --> 127 results = completion(
#     128     request=dict(model=self.model, messages=messages, **kwargs),
#     129     num_retries=self.num_retries,
#     130     cache=litellm_cache_args,
#     131 )
#     133 if any(c.finish_reason == "length" for c in results["choices"]):
#     134     logger.warning(
#     135         f"LM response was truncated due to exceeding max_tokens={self.kwargs['max_tokens']}. "
#     136         "You can inspect the latest LM interactions with `dspy.inspect_history()`. "
#    (...)    139         " if the reason for truncation is repetition."
#     140     )
#
# File ~/miniforge3/lib/python3.11/site-packages/dspy/clients/cache.py:232, in request_cache.<locals>.decorator.<locals>.sync_wrapper(*args, **kwargs)
#     229     return cached_result
#     231 # Otherwise, compute and store the result
# --> 232 result = fn(*args, **kwargs)
#     233 # `enable_memory_cache` can be provided at call time to avoid indefinite growth.
#     234 cache.put(modified_request, result, ignored_args_for_cache_key, enable_memory_cache)
#
# File ~/miniforge3/lib/python3.11/site-packages/dspy/clients/lm.py:304, in litellm_completion(request, num_retries, cache)
#     302 stream_completion = _get_stream_completion_fn(request, cache, sync=True)
#     303 if stream_completion is None:
# --> 304     return litellm.completion(
#     305         cache=cache,
#     306         num_retries=num_retries,
#     307         retry_strategy="exponential_backoff_retry",
#     308         **request,
#     309     )
#     311 return stream_completion()
#
# File ~/miniforge3/lib/python3.11/site-packages/litellm/utils.py:1163, in client.<locals>.wrapper(*args, **kwargs)
#    1161         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1162 # MODEL CALL
# -> 1163 result = original_function(*args, **kwargs)
#    1164 end_time = datetime.datetime.now()
#    1165 if "stream" in kwargs and kwargs["stream"] is True:
#
# File ~/miniforge3/lib/python3.11/site-packages/litellm/main.py:2478, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    2475     api_base = api_base or litellm.api_base or get_secret("GEMINI_API_BASE")
#    2477     new_params = deepcopy(optional_params)
# -> 2478     response = vertex_chat_completion.completion(  # type: ignore
#    2479         model=model,
#    2480         messages=messages,
#    2481         model_response=model_response,
#    2482         print_verbose=print_verbose,
#    2483         optional_params=new_params,
#    2484         litellm_params=litellm_params,  # type: ignore
#    2485         logger_fn=logger_fn,
#    2486         encoding=encoding,
#    2487         vertex_location=vertex_ai_location,
#    2488         vertex_project=vertex_ai_project,
#    2489         vertex_credentials=vertex_credentials,
#    2490         gemini_api_key=gemini_api_key,
#    2491         logging_obj=logging,
#    2492         acompletion=acompletion,
#    2493         timeout=timeout,
#    2494         custom_llm_provider=custom_llm_provider,
#    2495         client=client,
#    2496         api_base=api_base,
#    2497         extra_headers=extra_headers,
#    2498     )
#    2500 elif custom_llm_provider == "vertex_ai":
#    2501     vertex_ai_project = (
#    2502         optional_params.pop("vertex_project", None)
#    2503         or optional_params.pop("vertex_ai_project", None)
#    2504         or litellm.vertex_project
#    2505         or get_secret("VERTEXAI_PROJECT")
#    2506     )
#
# File ~/miniforge3/lib/python3.11/site-packages/litellm/llms/vertex_ai/gemini/vertex_and_google_ai_studio_gemini.py:1802, in VertexLLM.completion(self, model, messages, model_response, print_verbose, custom_llm_provider, encoding, logging_obj, optional_params, acompletion, timeout, vertex_project, vertex_location, vertex_credentials, gemini_api_key, litellm_params, logger_fn, extra_headers, client, api_base)
#    1799     client = client
#    1801 try:
# -> 1802     response = client.post(url=url, headers=headers, json=data)  # type: ignore
#    1803     response.raise_for_status()
#    1804 except httpx.HTTPStatusError as err:
#
# File ~/miniforge3/lib/python3.11/site-packages/litellm/llms/custom_httpx/http_handler.py:685, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     681 else:
#     682     req = self.client.build_request(
#     683         "POST", url, data=data, json=json, params=params, headers=headers, files=files, content=content  # type: ignore
#     684     )
# --> 685 response = self.client.send(req, stream=stream)
#     686 response.raise_for_status()
#     687 return response
#
# File ~/miniforge3/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/miniforge3/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/miniforge3/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/miniforge3/lib/python3.11/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/miniforge3/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/miniforge3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/miniforge3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/miniforge3/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/miniforge3/lib/python3.11/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/miniforge3/lib/python3.11/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/miniforge3/lib/python3.11/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/miniforge3/lib/python3.11/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/miniforge3/lib/python3.11/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/miniforge3/lib/python3.11/ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File ~/miniforge3/lib/python3.11/ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
